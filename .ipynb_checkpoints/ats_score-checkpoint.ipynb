# %%
import pandas as pd
from sentence_transformers import SentenceTransformer, util
from tqdm import tqdm

# %%
df = pd.read_csv("resume_job_pairs.csv")

# %%
df.head()
# Out:
#                                               resume  \
# 0  Abhishek Chaudhary \n   ac5712916@gmail.com  |...
# 1  Abhishek Chaudhary \n   ac5712916@gmail.com  |...
# 2  Abhishek Chaudhary \n   ac5712916@gmail.com  |...
# 3  Abhishek Chaudhary \n   ac5712916@gmail.com  |...
# 4  Abhishek Chaudhary \n   ac5712916@gmail.com  |...
#
#                                                   jd
# 0  Full job description\nPosition: Junior PHP Dev...
# 1  Full job description\nJob Summary:\n\nWe are s...
# 2  Job Title: Sr. Website UI/UX Designer and Deve...
# 3  We are looking for a passionate and enthusiast...
# 4  Full job description\nJob Title: Software Engi...

# %%
model = SentenceTransformer('all-MiniLM-L6-v2')

# %%
scores = []

# %%
for i, row in tqdm(df.iterrows(),total = len(df)):
    jd     = str(row['jd'])
    resume = str(row['resume'])

    embeddings = model.encode([jd, resume], convert_to_tensor= True)

    score = util.cos_sim(embeddings[0], embeddings[1]).item()

    scores.append(round(score* 100, 2))


df['ats_score'] = scores
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1560/1560 [02:22<00:00, 10.96it/s]

# %%
df.head()
# Out:
#                                               resume  \
# 0  Abhishek Chaudhary \n   ac5712916@gmail.com  |...
# 1  Abhishek Chaudhary \n   ac5712916@gmail.com  |...
# 2  Abhishek Chaudhary \n   ac5712916@gmail.com  |...
# 3  Abhishek Chaudhary \n   ac5712916@gmail.com  |...
# 4  Abhishek Chaudhary \n   ac5712916@gmail.com  |...
#
#                                                   jd  ats_score
# 0  Full job description\nPosition: Junior PHP Dev...      26.76
# 1  Full job description\nJob Summary:\n\nWe are s...      21.37
# 2  Job Title: Sr. Website UI/UX Designer and Deve...      36.91
# 3  We are looking for a passionate and enthusiast...      30.80
# 4  Full job description\nJob Title: Software Engi...      27.04

# %%
df.to_csv("final_dataset.csv", index= False, encoding= 'utf-8')

# %%
final_df = pd.read_csv('final_dataset.csv')

# %%
final_df.head()
# Out:
#                                               resume  \
# 0  Abhishek Chaudhary \n   ac5712916@gmail.com  |...
# 1  Abhishek Chaudhary \n   ac5712916@gmail.com  |...
# 2  Abhishek Chaudhary \n   ac5712916@gmail.com  |...
# 3  Abhishek Chaudhary \n   ac5712916@gmail.com  |...
# 4  Abhishek Chaudhary \n   ac5712916@gmail.com  |...
#
#                                                   jd  ats_score
# 0  Full job description\nPosition: Junior PHP Dev...      26.76
# 1  Full job description\nJob Summary:\n\nWe are s...      21.37
# 2  Job Title: Sr. Website UI/UX Designer and Deve...      36.91
# 3  We are looking for a passionate and enthusiast...      30.80
# 4  Full job description\nJob Title: Software Engi...      27.04
