# %%
from docx import Document

# --- User Data (you can edit this) ---
name = "Priyanshu"
role = "Data Scientist"
email = "priyanshu@example.com"
skills = ["Python", "Machine Learning", "NLP", "Streamlit", "SQL"]
experience = [
    "Built a Brain Tumor Detection model using CNNs",
    "Developed MedVision, a Streamlit-based healthcare app",
    "Internship at XYZ Company as Data Analyst"
]

# --- Create Document ---
doc = Document()

doc.add_heading("Resume", level=1)

doc.add_paragraph(f"Name: {name}")
doc.add_paragraph(f"Role: {role}")
doc.add_paragraph(f"Email: {email}")

doc.add_heading("Skills", level=2)
for skill in skills:
    doc.add_paragraph(skill, style="ListBullet")

doc.add_heading("Experience", level=2)
for exp in experience:
    doc.add_paragraph(exp, style="ListBullet")

# --- Save File ---
doc.save("resume.docx")

print("✅ Resume generated successfully! Check 'resume.docx'")
# Out:
# ✅ Resume generated successfully! Check 'resume.docx'
# C:\Users\Mahadev\AppData\Local\Programs\Python\Python312\Lib\site-packages\docx\styles\styles.py:130: UserWarning: style lookup by style_id is deprecated. Use style name as key instead.
#   return self._get_style_id_from_style(self[style_name], style_type)

# %%
from docx import Document
from docx.shared import Pt, RGBColor

# Create a new document
doc = Document()

# ======================
# HEADER
# ======================
p = doc.add_paragraph("PRIYANSHU GUPTA")
p.alignment = 1  # center
run = p.runs[0]
run.bold = True
run.font.size = Pt(16)

p = doc.add_paragraph("abcdlorem@gmail.com | +91 99999-99999 | GitHub | LinkedIn")
p.alignment = 1  # center
p.runs[0].font.size = Pt(10)

# ======================
# SECTION FUNCTION
# ======================
def add_section(title):
    p = doc.add_paragraph(title)
    run = p.runs[0]
    run.bold = True
    run.font.color.rgb = RGBColor(0, 51, 153)  # Dark Blue
    run.font.size = Pt(12)

# ======================
# EDUCATION
# ======================
add_section("Education")

table = doc.add_table(rows=3, cols=2)
education = [
    ("DAV Institute of Engineering and Technology, Punjab, India\nCSE | CGPA: 7.9", "2023-2026"),
    ("Mehr Chand Polytechnic College, Punjab, India\nCSE | Percentage: 81%", "2020-2023"),
    ("Shree Mahavir Jain Sen. Sec Model School, India\nPSEB (Class X), Percentage: 90%", "2019-2020")
]
for i, (inst, years) in enumerate(education):
    row = table.rows[i].cells
    row[0].text = inst
    row[1].text = years

# ======================
# SKILLS
# ======================
add_section("Skills")

doc.add_paragraph().add_run("Programming Languages: ").bold = True
doc.paragraphs[-1].add_run("Python, C++, SQL, Kotlin")

doc.add_paragraph().add_run("Machine Learning: ").bold = True
doc.paragraphs[-1].add_run("Regression, Classification, Clustering, Model Evaluation")

doc.add_paragraph().add_run("Deep Learning: ").bold = True
doc.paragraphs[-1].add_run("CNNs, TensorFlow")

doc.add_paragraph().add_run("Libraries: ").bold = True
doc.paragraphs[-1].add_run("scikit-learn, TensorFlow, NumPy, pandas")

doc.add_paragraph().add_run("Data Analysis & Visualization: ").bold = True
doc.paragraphs[-1].add_run("EDA, Feature Engineering, Matplotlib, Plotly, Streamlit")

doc.add_paragraph().add_run("Database & Tools: ").bold = True
doc.paragraphs[-1].add_run("MySQL, SQL Plus, Power BI, Firebase, Jupyter Notebook, Git")

# ======================
# PROJECTS
# ======================
add_section("Projects")

projects = [
    {
        "title": "MedVision (Brain Tumor Detection — CNN, Python, TensorFlow)",
        "time": "5 Weeks | March 2025 | GitHub Link",
        "bullets": [
            "Developed a deep learning-based system to detect brain tumors from MRI scans using CNNs.",
            "Designed a Streamlit web interface to provide doctors with reliable diagnostic support.",
            "Handled preprocessing, augmentation, and achieved over 90% accuracy."
        ]
    },
    {
        "title": "House Price Prediction (Random Forest, XGBoost)",
        "time": "3 Weeks | Dec 2024 | GitHub Link",
        "bullets": [
            "Built a regression model for house price estimation using ensemble learning.",
            "Conducted EDA, handled missing data, and improved model performance with hyperparameter tuning."
        ]
    },
    {
        "title": "Pandemic Insight (COVID-19 Data Analysis — Pandas, NumPy, Streamlit)",
        "time": "6 Weeks | Mar 2024 | GitHub Link",
        "bullets": [
            "Developed a Streamlit-based application for COVID-19 data analysis.",
            "Visualized global and Indian COVID-19 trends with interactive plots.",
            "Utilized Pandas and NumPy for data processing and Plotly for visualization."
        ]
    }
]

for proj in projects:
    p = doc.add_paragraph(proj["title"])
    p.runs[0].bold = True
    doc.add_paragraph(proj["time"])
    for b in proj["bullets"]:
        doc.add_paragraph(b, style="ListBullet")

# ======================
# CERTIFICATIONS
# ======================
add_section("Certifications & Courses")
certs = [
    ("Android App Development with Kotlin — Beginner to Advanced", "March 2023"),
    ("Data Science & Python", "July 2024"),
    ("Machine Learning with Python", "Feb 2025"),
]
for c, date in certs:
    doc.add_paragraph(f"{c} ({date})", style="ListBullet")

# ======================
# ACHIEVEMENTS
# ======================
add_section("Achievements & Activities")
achievements = [
    "Solved 150+ DSA questions on platforms like LeetCode and Coding Ninjas.",
    "Presented COVID-19 analysis project during academic viva.",
    "Writing a review paper on 'The Impact of Data Science in Sports Analytics'."
]
for a in achievements:
    doc.add_paragraph(a, style="ListBullet")

# ======================
# HOBBIES
# ======================
add_section("Hobbies")
hobbies = [
    "Solving coding challenges and algorithmic puzzles.",
    "Passionate about data analysis and uncovering insights.",
    "Strategic thinker — enjoy logic-based games.",
    "Enthusiastic about emerging tech and AI advancements."
]
for h in hobbies:
    doc.add_paragraph(h, style="ListBullet")

# ======================
# SAVE DOCUMENT
# ======================
doc.save("resumeff.docx")
print("✅ Resume generated successfully! Check 'resume.docx'")
# Out:
# ✅ Resume generated successfully! Check 'resume.docx'
# C:\Users\Mahadev\AppData\Local\Programs\Python\Python312\Lib\site-packages\docx\styles\styles.py:130: UserWarning: style lookup by style_id is deprecated. Use style name as key instead.
#   return self._get_style_id_from_style(self[style_name], style_type)
